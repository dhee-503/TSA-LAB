# %%
# Step 1: Install necessary packages
# !pip install pandas numpy matplotlib scikit-learn tensorflow --quiet

# Step 2: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error
import math

# Step 3: Load Dataset
df = pd.read_csv('/content/airline-passengers.csv')
print(df.head())

# Step 4: Preprocess Data
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)
data = df['Passengers'].values
data = data.reshape(-1, 1)

# Normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# Step 5: Create Dataset for Supervised Learning
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 10  # you can change this
X, y = create_dataset(data, look_back)

# Reshape input to [samples, time steps, features] for LSTM
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Step 6: Split into train/test sets
train_size = int(len(X) * 0.67)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Step 7: Build the LSTM Model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Step 8: Train the Model
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)

# Step 9: Predict
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train_inv = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test_inv = scaler.inverse_transform([y_test])

# Step 10: Calculate RMSE
train_score = math.sqrt(mean_squared_error(y_train_inv[0], train_predict[:, 0]))
test_score = math.sqrt(mean_squared_error(y_test_inv[0], test_predict[:, 0]))
print(f'Train RMSE: {train_score:.2f}')
print(f'Test RMSE: {test_score:.2f}')

# Step 11: Visualize Results
train_plot = np.empty_like(data)
train_plot[:, :] = np.nan
train_plot[look_back:look_back + len(train_predict)] = train_predict

test_plot = np.empty_like(data)
test_plot[:, :] = np.nan
test_plot[look_back + len(train_predict):] = test_predict

# Plot baseline and predictions
plt.figure(figsize=(12,6))
plt.plot(scaler.inverse_transform(data), label="Actual Data")
plt.plot(train_plot, label="Train Prediction")
plt.plot(test_plot, label="Test Prediction")
plt.title("Airline Passenger Forecast using LSTM")
plt.xlabel("Time")
plt.ylabel("Passengers")
plt.legend()
plt.grid()
plt.show()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0150
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0058
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0036
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0040
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0029
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0027
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0017
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0021
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0025
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0026
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0021
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0018
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 48/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0014
# Epoch 62/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018
# Epoch 63/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 65/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 68/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5991e-04
# Epoch 69/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014
# Epoch 70/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 71/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 73/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013
# Epoch 74/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 75/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 76/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 77/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013
# Epoch 80/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 81/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0015
# Epoch 82/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4590e-04
# Epoch 83/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011
# Epoch 84/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 85/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.4919e-04
# Epoch 86/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 87/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 88/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.6709e-04
# Epoch 89/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 90/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 91/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 92/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 93/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0010
# Epoch 94/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 95/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 96/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9327e-04
# Epoch 97/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8664e-04
# Epoch 98/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 99/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 100/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Train RMSE: 16.79
# Test RMSE: 67.31
